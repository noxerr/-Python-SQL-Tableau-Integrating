# %%
from absenteeism_module import *

# %%
#import importlib, absenteeism_module
#importlib.reload(absenteeism_module)

# %%
#pd.read_csv('Absenteeism_new_data.csv')

# %%
#model = absenteeism_model('Model_name_reg_absent', 'Model_name_scaler')
model = absenteeism_model('Model_name_reg_absent', 'Model_name_scaler')

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %%
import pymysql as pmy

# %%
conn = pmy.connect(database = 'predicted_outputs', user = 'root', password = 'Davidro12')

# %%
cursor = conn.cursor()

# %%
df_new_obs = model.predicted_outputs()
#df_new_obs.info()

# %%
#cursor.execute('SELECT * FROM df_new_obs;')
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 40

# %%
queryInsert = 'INSERT INTO predicted_outputs VALUES '

# %%
#queryInsert = ''
for i in range(df_new_obs.shape[0]):
    queryInsert += '('
    
    for j in range(df_new_obs.shape[1]):
        queryInsert += str(df_new_obs.iat[i,j])
        queryInsert += ', '
    queryInsert = queryInsert[:-2] + '),'    
queryInsert = queryInsert[:-1] + ';'

# %%
#print(queryInsert)
queryInsert
# Out:
# 'INSERT INTO predicted_outputs VALUES (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1272026840016058, 0),(1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8640291016333899, 1),(0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.2650964306564385, 0),(0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.20289411791478118, 0),(1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7194128174546239, 1),(1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7079782480115632, 1),(1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.570469320993404, 1),(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1272026840016058, 0),(0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.1339092491659574, 0),(1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5235747902795651, 1),(0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.43745784439397783, 0),(0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6396948957990345, 1),(0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.3447409117005028, 0),(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1272026840016058, 0),(0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.07740378316749244, 0),(0, 0.0, 0, 0
# ...

# %%
cursor.execute(queryInsert)
# Out:
# 40

# %%
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 40

# %%
conn.commit()

# %%
conn.close()
